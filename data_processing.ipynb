# %%
import pandas as pd
import json

data2 = "data2.json"
data3 = "data3.json"
data4 = "data4.json"

with open(data4) as f:
    data = json.load(f)

df = pd.DataFrame(list(data.values()))

df.to_csv("business_analyst_jobs.csv", index=False)

# %%
import pandas as pd

data = "all_jobs.csv"

df = pd.read_csv(data)

df
# Out:
#                                                   title  \
# 0                                      Business Analyst
# 1                           Business Analyst (Contract)
# 2                                      Business Analyst
# 3                                      Business Analyst
# 4                                      Business Analyst
# ...                                                 ...
# 1793                          Machine Learning Engineer
# 1794                              Senior Data Scientist
# 1795  Associate Data Scientist - IntelliScript (Remote)
# 1796                                 Sr. Data Scientist
# 1797                        Senior Level Data Scientist
#
#                              company                   location   salary  \
# 0                          Capgemini  New Jersey, United States  Unknown
# 1     Sony Interactive Entertainment              United States  Unknown
# ...
